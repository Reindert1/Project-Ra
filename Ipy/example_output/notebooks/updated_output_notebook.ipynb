# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/homes/kanotebomer/Documents/Thema11/Project-Ra/venv/lib/python3.9/site-packages', '/homes/kanotebomer/Documents/Thema11/Project-Ra/Ipy/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xb9\x08\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8ca/commons/Themas/Thema11/Giepmans/work/small_test_6/images/overlayed/train_SVMsampling_overlay.tif\x94\x8c`/commons/Themas/Thema11/Giepmans/work/small_test_6/images/overlayed/test_SVMsampling_overlay.tif\x94\x8ch/commons/Themas/Thema11/Giepmans/work/small_test_6/images/overlayed/test_matched_SVMsampling_overlay.tif\x94\x8cP/commons/Themas/Thema11/Giepmans/work/small_test_6/model_metrics/SVMsampling.sav\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x06images\x94K\x00K\x03\x86\x94\x8c\x07metrics\x94K\x03K\x04\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x17\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1d)}\x94\x8c\x05_name\x94h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bh\x11h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ce}\x94(h\x0f}\x94h\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bubh\x13h()\x81\x94h\ra}\x94(h\x0f}\x94h\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c@/commons/Themas/Thema11/Giepmans/work/small_test_6/notebook.done\x94a}\x94(h\x0f}\x94h\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bhwK\x01hyK\x01h{htub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cR/commons/Themas/Thema11/Giepmans/work/small_test_6/notebooks/output_notebook.ipynb\x94a}\x94(h\x0f}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x15]\x94(h\x17h\x18eh\x17h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x17sNt\x94bh\x18h\x1bh\x1d\x85\x94R\x94(h\x1d)}\x94h!h\x18sNt\x94bh\x8dh\x8aub\x8c\x06config\x94}\x94(\x8c\x07datadir\x94\x8c!/commons/Themas/Thema11/Giepmans/\x94\x8c\x0bdataset_dir\x94\x8cC/local-fs/bachelor-students/2021-2022/Thema12/ra_data/small_test_6/\x94\x8c\x0bresults_dir\x94\x8c3/commons/Themas/Thema11/Giepmans/work/small_test_6/\x94\x8c\ntrain_data\x94\x8c\x1awork/train_small_r4_c7.tif\x94\x8c\x0bclassifiers\x94}\x94\x8c\x07nucleus\x94\x8c\x17work/r4-c4nuc_small.tif\x94s\x8c\x07segment\x94}\x94(\x8c\x05train\x94\x8c\x1awork/train_small_r4_c7.tif\x94\x8c\x04test\x94\x8c\x19work/test_small_r4_c4.tif\x94\x8c\x0ctest_matched\x94\x8c\x16work/matched_small.tif\x94u\x8c\x0fgaussian_layers\x94K\x06\x8c\x0bwindow_size\x94K\nK\n\x86\x94\x8c\nalgorithms\x94]\x94\x8c\x0bSVMsampling\x94au\x8c\x04rule\x94\x8c\x16create_output_notebook\x94\x8c\x0fbench_iteration\x94K\x00\x8c\tscriptdir\x94\x8cO/homes/kanotebomer/Documents/Thema11/Project-Ra/Ipy/workflow/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/homes/kanotebomer/Documents/Thema11/Project-Ra/Ipy');
######## snakemake preamble end #########

# %%
import os
import PIL
import pickle
import math
from PIL import Image
from mpl_toolkits.axes_grid1 import ImageGrid
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
PIL.Image.MAX_IMAGE_PIXELS = 268435460

# %%
for pickled_metric in snakemake.input["metrics"]:
    with open(pickled_metric, 'rb') as handle:
        metric_dict = pickle.load(handle)
        for key, value in metric_dict.items():
            #print ("{:<10} {:<10}".format(key, value))
            print (f"{key}: {value}")
        print()
# Out:
# Model: SVM_sampling
# Train_Accuracy: 0.836375
# Test_Accuracy: 0.8337755038654627
# confus_matrix: [[121949  30339]
#  [116837 616280]]
# balanced_accuracy_score: 0.8207042957672013

# %%
image_locs = snakemake.input["images"]
nrows = math.ceil(len(image_locs)/3)
fig = plt.figure(figsize=(14, 14), dpi=100)
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(nrows, 3),  # creates 2x2 grid of axes
                 axes_pad=(0.2, 0.3),  # pad between axes in inch.
                 )

for axis in grid:
    axis.axis('off')

for axis, file_name in zip(grid, image_locs):
    img = Image.open(file_name, 'r')
    axis.imshow(img)
    axis.set_title(os.path.basename(file_name), fontsize=8)
